# %%
import data_processing_utils
import importlib
importlib.reload(data_processing_utils)
# Out:
# <module 'data_processing_utils' from 'C:\\Users\\MainUser\\project\\cs224w_cb_graph\\data_processing_utils.py'>

# %%
author_name = "m:miran-stephen-i" #"j:jefferson-philip-n" #"p:powell-jerome-h"
# "w:williams-john-c"
# "w:williams-john-c"
# "b:bowman-michelle-w"

data = data_processing_utils.query_fed_prints_by_author(author_name)
pdf_links = data_processing_utils.retrieve_remaining_ids(author_name, data)
author_short_name = data_processing_utils.get_author_short_name(author_name)
data_processing_utils.pdfs_to_json(pdf_links, f"text_data/{author_short_name}.json")
# Out:
# 3
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/miran20250922a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/miran20251107a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}
# file {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/miran20251119a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}
# 3
# 3
# Processing PDFs: 100%|██████████| 3/3 [00:02<00:00,  1.15it/s]
# Saved 3 entries → text_data/miran.json
