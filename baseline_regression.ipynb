# %%
import analysis_utils
import importlib
importlib.reload(analysis_utils)
# Out:
# <module 'analysis_utils' from 'C:\\Users\\MainUser\\project\\cs224w_cb_graph\\analysis_utils.py'>

# %%
scores_by_date_average = analysis_utils.load_topic_scores_by_date()
scores_by_date = analysis_utils.load_topic_scores_by_date(apply_average=False)

# %%
average_curve = {}
for key, value in scores_by_date_average.items():
    rate = value["Fed Funds Rate"]
    if rate == 0:
        continue 
    average_curve[key] = value["Fed Funds Rate"]
average_curve = dict(sorted(average_curve.items()))

curve = {}
for key, value in scores_by_date.items():
    rate = value["Fed Funds Rate"]
    if rate == 0:
        continue 
    curve[key] = value["Fed Funds Rate"]
curve = dict(sorted(curve.items()))

# %%
import pandas as pd 
score_df = pd.DataFrame.from_dict(curve, orient="index", columns=["Score"])
score_df.index = pd.to_datetime(score_df.index)
score_df = score_df.sort_index()

print(score_df.head())
# Out:
#             Score
# 2018-06-18   0.20
# 2018-06-19   0.20
# 2018-06-20   0.75
# 2018-06-27   0.50
# 2018-08-21   0.70

# %%
rate_df  = analysis_utils.load_rates()
rate_df["Rate_Change"] = rate_df["Rate"].diff()
print(rate_df)
rate_dict = rate_df["Rate"].to_dict()
# Out:
#                 Rate  Rate_Change
# 2018-06-18  2.206554          NaN
# 2018-06-19  2.200748    -0.005806
# 2018-06-20  2.199854    -0.000893
# 2018-06-27  2.216622     0.016768
# 2018-07-18  2.292537     0.075915
# ...              ...          ...
# 2025-11-12  3.431500     0.000000
# 2025-11-17  3.431500     0.000000
# 2025-11-18  3.431500     0.000000
# 2025-11-19  3.431500     0.000000
# 2025-11-21  3.431500     0.000000
#
# [647 rows x 2 columns]

# %%
df = score_df.join(rate_df, how="inner")
print(df)
print(df.shape)
# Out:
#             Score      Rate  Rate_Change
# 2018-06-18   0.20  2.206554          NaN
# 2018-06-19   0.20  2.200748    -0.005806
# 2018-06-20   0.75  2.199854    -0.000893
# 2018-06-27   0.50  2.216622     0.016768
# 2018-08-21   0.70  2.328444    -0.015634
# ...           ...       ...          ...
# 2025-10-14  -0.40  3.449556    -0.095937
# 2025-10-16  -0.85  3.367280    -0.084573
# 2025-10-31   0.50  3.431500     0.000000
# 2025-11-17  -0.95  3.431500     0.000000
# 2025-11-21  -0.80  3.431500     0.000000
#
# [423 rows x 3 columns]
# (423, 3)

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from statsmodels) (2.3.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from statsmodels) (1.16.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# --- Create regression target (next-day change) ---
import statsmodels.api as sm

df["Y"] = df["Rate_Change"]
df = df.dropna()

# --- Chronological split (80% / 20%) ---
n = len(df)
n_train = int(n * 0.8)

df_train = df.iloc[:n_train]
df_test  = df.iloc[n_train:]

print("Train size:", df_train.shape)
print("Test size:", df_test.shape)

# --- Prepare train data ---
X_train = sm.add_constant(df_train["Score"])
y_train = df_train["Y"]

# --- Fit model on TRAIN ONLY ---
model = sm.OLS(y_train, X_train).fit()
print(model.summary())

# --- Predict in-sample ---
y_train_pred = model.predict(X_train)

# --- Predict out-of-sample ---
X_test = sm.add_constant(df_test["Score"])
y_test = df_test["Y"]
y_test_pred = model.predict(X_test)

# --- Compute RMSE ---
rmse_train = ((y_train - y_train_pred)**2).mean()
rmse_test  = ((y_test  - y_test_pred)**2).mean()

print("Train RMSE:", rmse_train**0.5)
print("Test RMSE:", rmse_test**0.5)
# Out:
# Train size: (337, 4)
# Test size: (85, 4)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     28.82
# Date:                Thu, 11 Dec 2025   Prob (F-statistic):           1.48e-07
# Time:                        18:59:10   Log-Likelihood:                 352.42
# No. Observations:                 337   AIC:                            -700.8
# Df Residuals:                     335   BIC:                            -693.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0105      0.005      2.249      0.025       0.001       0.020
# Score          0.0392      0.007      5.369      0.000       0.025       0.054
# ==============================================================================
# Omnibus:                      254.184   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6789.975
# Skew:                           2.779   Prob(JB):                         0.00
# Kurtosis:                      24.276   Cond. No.                         1.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Train RMSE: 0.08503512845397182
# Test RMSE: 0.08095968265696268

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with a secondary Y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# ---d- First trace (left Y-axis) ----
fig.add_trace(
    go.Scatter(
        x=list(average_curve.keys()),
        y=list(average_curve.values()),
        name="Hawkish/Dovish Score",
        #line=dict(color="blue")
    ),
    secondary_y=False
)

# ---- Second trace (right Y-axis) ----
fig.add_trace(
    go.Scatter(
        x=list(rate_dict.keys()),
        y=list(rate_dict.values()),
        name="Rate",
    ),
    secondary_y=True
)



# Add axis titles
fig.update_layout(
    xaxis_title="Date"
)

fig.update_yaxes(title_text="Average Score", secondary_y=False)
fig.update_yaxes(title_text="Score", secondary_y=True)

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with a secondary Y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# --- First trace (left Y-axis) ---
fig.add_trace(
    go.Scatter(
        x=list(average_curve.keys()),
        y=list(average_curve.values()),
        name="Hawkish/Dovish Score",
    ),
    secondary_y=False
)

# --- Second trace (right Y-axis) ---
fig.add_trace(
    go.Scatter(
        x=list(rate_dict.keys()),
        y=list(rate_dict.values()),
        name="Rate",
    ),
    secondary_y=True
)

# Layout updates: remove grid + horizontal legend top right
fig.update_layout(
    xaxis_title="Date",
    legend=dict(
        orientation="h",  # horizontal
        x=0.98,
        y=1.05,  # slightly above the plot
        xanchor="right",
        yanchor="bottom",
        bgcolor="rgba(0,0,0,0)"  # fully transparent
    )
)

# Remove gridlines
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False, secondary_y=False)
fig.update_yaxes(showgrid=False, secondary_y=True)

# Y-axis titles
fig.update_yaxes(title_text="Average Score", secondary_y=False)
fig.update_yaxes(title_text="Rate", secondary_y=True)

fig.show()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with a secondary Y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# --- First trace (left Y-axis) ---
fig.add_trace(
    go.Scatter(
        x=list(average_curve.keys()),
        y=list(average_curve.values()),
        name="Hawkish/Dovish Score of Topic 'Fed Funds Rate'",
    ),
    secondary_y=False
)

# --- Second trace (right Y-axis) ---
fig.add_trace(
    go.Scatter(
        x=list(rate_dict.keys()),
        y=list(rate_dict.values()),
        name="Rate (%)",
    ),
    secondary_y=True
)

# Layout updates: remove grid + horizontal legend top right
fig.update_layout(
    xaxis_title="Date",
    legend=dict(
        orientation="h",  # horizontal
        x=0.98,
        y=1.05,  # slightly above the plot
        xanchor="right",
        yanchor="bottom",
        bgcolor="rgba(0,0,0,0)"  # fully transparent
    )
)

# Remove gridlines
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False, secondary_y=False)
fig.update_yaxes(showgrid=False, secondary_y=True)

# Y-axis titles
fig.update_yaxes(title_text="Score", secondary_y=False)
fig.update_yaxes(title_text="Rate (%)", secondary_y=True)
fig.write_image("dh_score.png")
#fig.show()

# %%
# %pip install -U kaleido
# Out:
# Requirement already satisfied: kaleido in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (1.2.0)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from kaleido) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from kaleido) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from kaleido) (3.11.5)
# Requirement already satisfied: packaging in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from kaleido) (25.0)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from kaleido) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from choreographer>=1.1.1->kaleido) (3.20.2)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pytest-timeout>=2.4.0->kaleido) (9.0.2)
# Requirement already satisfied: colorama>=0.4 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (0.4.6)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\mainuser\project\cs224w_cb_graph\.venv\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
