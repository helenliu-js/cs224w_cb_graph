# %%
API_KEY = "f76029a3a9cd0c9eeb480679c9a77fe8"
author_name = "b:bowman-michelle-w"

# %%
import requests

url = f"https://fedinprint.org/api/author/{author_name}/items"
params = {
    "limit": 10000
}
headers = {
    "x-api-key": API_KEY
}
response = requests.get(url, params=params, headers=headers)
data = response.json()
print(len(data["records"]))
# Out:
# 131

# %%
import json

def get_ids():
    with open(f"text_data_old/bowman.json", "r", encoding="utf-8") as f:
        text_data = json.load(f)
        return list(map(lambda x: x["id"], text_data))

# %%
ids = get_ids()
records = data["records"]
idx = 0

for record in records:
    #print(record)
    if record["id"] in ids:
        continue
    if "file" not in record:
        continue
    if "fedlwp" in record["id"]:
        continue
    if "fedhwp" in record["id"]:
        continue
    if "fedcwp" in record["id"]:
        continue
    if "fedlrv" in record["id"]:
        continue
    if "fedgfn" in record["id"]:
        continue
    if "fedgfe" in record["id"]:
        continue
    if "fedlre" in record["id"]:
        continue
    if "fedlar" in record["id"]:
        continue
    if "fedcer" in record["id"]:
        continue
    if "fedles" in record["id"]:
        continue
    if "fedlps" in record["id"]:
        continue
    if "fedcwq" in record["id"]:
        continue
    if "fedfci" in record["id"]:
        continue
    if "fedkcc" in record["id"]:
        continue
    if "fedfmo" in record["id"]:
        continue
    record_id = record["id"]
    print(record["id"])
    print(record["file"])
    idx += 1

print(idx)
# Out:
# fedgsq:101411
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250809a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95805
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220930a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95632
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230213a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97103
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231011a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96332
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230531a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95850
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230314a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98438
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240625a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:101934
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20251009b.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:93760
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220221a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95813
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20221012a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97620
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240117a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95655
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230215a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:93038
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20210909a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96371
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230622a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:97024
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231004a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97859
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240227a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95833
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230213a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:22952
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20190211a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97724
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/bowman20240202a.htm', 'fileformat': 'text/html', 'filefunction': 'Full text'}, {'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240202a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97385
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231128a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98807
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240920a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98907
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20241002a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:101952
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20251016a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:94655
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220817b.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96525
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230805a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98390
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240617a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:93162
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20211013a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96526
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230807a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97905
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240305a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:89074
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/bowman20201119a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:87530
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20200227a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97099
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231007a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:101136
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250623a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:96391
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230625a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:87380
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20200116a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98180
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240503a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:22624
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20190411a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:99635
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250227a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:93100
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20210928a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97026
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231002a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96153
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230512a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:102005
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20251030a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95795
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220817a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98255
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240517a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:97172
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231017a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:93328
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20211108a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:93410
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20211129a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:92806
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/bowman20210623a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98440
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240625b.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:101890
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20251007a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:90394
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20210322a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:94574
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220806a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96016
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230418a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96599
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230822a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95803
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220928a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98874
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240930a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98442
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240626a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:89973
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/bowman20210222a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98034
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240405a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:88607
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20200819a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98460
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240627a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:22692
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20190904a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95796
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20220817b.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95817
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20221117a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98576
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240718a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:99014
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20241023a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98960
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20241011a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:97745
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240212a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95815
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20221020a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:22379
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20191001a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:96006
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230414a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97754
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240215a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95834
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230215a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:22560
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20190625a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:101843
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250926a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:88816
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20200930a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:22837
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20190325a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97174
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231018a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:88647
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20200826a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:99514
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250205a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:96031
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230420a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:97251
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231107a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98535
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240710a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:93272
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20211022a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:95738
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230303a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98857
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240926a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98216
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240510a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98654
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240810a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:95839
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230303a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:101840
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250923a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:97299
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20231109a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:96968
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230926a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:98126
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240418a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98020
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240403a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:99511
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20250109a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:96967
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230922a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:101914
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20251009a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98779
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240910a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:98612
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20240724a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full Text'}]
# fedgsq:96969
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20230927a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:91397
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/bowman20210505a.htm', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# fedgsq:22714
# [{'fileurl': 'https://www.federalreserve.gov/newsevents/speech/files/bowman20191017a.pdf', 'fileformat': 'application/pdf', 'filefunction': 'Full text'}]
# 102
